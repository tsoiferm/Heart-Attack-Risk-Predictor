# %%
import pandas as pd
from matplotlib import pyplot as plt

#load in data
heart = pd.read_csv(r"C:\Users\twsoi\OneDrive - stevens.edu\COVID Severity Predictor\heart.csv")
heart.head(60)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
#max absolute scale data
heart_max_scaled = heart.copy()
for column in heart_max_scaled.columns:
    heart_max_scaled[column] = heart_max_scaled[column]/heart_max_scaled[column].abs().max()
    
heart = heart_max_scaled

heart
# Out:
#           age  sex        cp  trestbps      chol  fbs  restecg   thalach  \
# 0    0.818182  1.0  1.000000     0.725  0.413121  1.0      0.0  0.742574
# 1    0.480519  1.0  0.666667     0.650  0.443262  0.0      0.5  0.925743
# 2    0.532468  0.0  0.333333     0.650  0.361702  0.0      0.0  0.851485
# 3    0.727273  1.0  0.333333     0.600  0.418440  0.0      0.5  0.881188
# 4    0.740260  0.0  0.000000     0.600  0.627660  0.0      0.5  0.806931
# ..        ...  ...       ...       ...       ...  ...      ...       ...
# 298  0.740260  0.0  0.000000     0.700  0.427305  0.0      0.5  0.608911
# 299  0.584416  1.0  1.000000     0.550  0.468085  0.0      0.5  0.653465
# 300  0.883117  1.0  0.000000     0.720  0.342199  1.0      0.5  0.698020
# 301  0.740260  1.0  0.000000     0.650  0.232270  0.0      0.5  0.569307
# 302  0.740260  0.0  0.333333     0.650  0.418440  0.0      0.0  0.861386
#
#      exang   oldpeak  slope    ca      thal  target
# ...

# %%
heart.shape
# Out:
# (303, 14)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#features
X = heart.drop(['target'], axis = 'columns')
X.head()
# Out:
#         age  sex        cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.818182  1.0  1.000000     0.725  0.413121  1.0      0.0  0.742574    0.0
# 1  0.480519  1.0  0.666667     0.650  0.443262  0.0      0.5  0.925743    0.0
# 2  0.532468  0.0  0.333333     0.650  0.361702  0.0      0.0  0.851485    0.0
# 3  0.727273  1.0  0.333333     0.600  0.418440  0.0      0.5  0.881188    0.0
# 4  0.740260  0.0  0.000000     0.600  0.627660  0.0      0.5  0.806931    1.0
#
#     oldpeak  slope   ca      thal
# 0  0.370968    0.0  0.0  0.333333
# 1  0.564516    0.0  0.0  0.666667
# 2  0.225806    1.0  0.0  0.666667
# 3  0.129032    1.0  0.0  0.666667
# 4  0.096774    1.0  0.0  0.666667

# %%
#target
y = heart.iloc[:,-1]

# %%
#train, test, split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=897)

# %%
len(X_train)
# Out:
# 242

# %%
len(X_test)
# Out:
# 61

# %%
from sklearn.svm import SVC
model = SVC()

# %%
#fitting and training 
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88        25
#          1.0       0.92      0.92      0.92        36
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61

# %%
model.score(X_test, y_test)
# Out:
# 0.9016393442622951

# %%
#testing other parameters
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1,5,15,50,10,100],
              'gamma': [0.5,0.7, 1, 0.001, 0.01],
              'kernel': ['rbf']}
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)

grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END .....................C=1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 2/5] END .....................C=1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 3/5] END .....................C=1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 4/5] END .....................C=1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 5/5] END .....................C=1, gamma=0.5, kernel=rbf; total time=   0.0s
# [CV 1/5] END .....................C=1, gamma=0.7, kernel=rbf; total time=   0.0s
# [CV 2/5] END .....................C=1, gamma=0.7, kernel=rbf; total time=   0.0s
# [CV 3/5] END .....................C=1, gamma=0.7, kernel=rbf; total time=   0.0s
# [CV 4/5] END .....................C=1, gamma=0.7, kernel=rbf; total time=   0.0s
# [CV 5/5] END .....................C=1, gamma=0.7, kernel=rbf; total time=   0.0s
# [CV 1/5] END .......................C=1, gamma=1, kernel=rbf; total time=   0.0s
# ...

# %%
#initial model has best/same accuracy and better recall
alt_model = SVC(C=5, gamma=1)
alt_model.fit(X_train, y_train)
pred = alt_model.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88        25
#          1.0       0.92      0.92      0.92        36
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61

# %%
model.score(X_test, y_test)
# Out:
# 0.9016393442622951

# %%
import pickle

# %%
the_data = {'model': model}
with open('saved_steps_final.pkl', 'wb') as file:
    pickle.dump(the_data, file)

# %%
with open('saved_steps_final.pkl', 'rb') as file:
    final_data = pickle.load(file)

# %%
svm_loaded = final_data["model"]

# %%
y_pred = svm_loaded.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88        25
#          1.0       0.92      0.92      0.92        36
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
